# %%
# First let's import the packages we will use in this project
# We do this all now or as we need them

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None


# Now we need to read in the data
df = pd.read_csv(r'/Users/vietthanhphan/Downloads/movies.csv')

# %%
df['year'].sort_values().max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0       1980
# 66      1980
# 65      1980
# 64      1980
# 63      1980
#         ...
# 7645    2020
# 7644    2020
# 7666    2020
# 7654    2020
# 7667    2020
# Name: year, Length: 7668, dtype: int64>

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %% [markdown]
# ### Remove Country from 'released'

# %%
df['date_released_afterremoved'] = df['released'].str.split("\s+\(").str[0]
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime date_released_afterremoved
# 0   46998772.0        Warner Bros.    146.0              June 13, 1980
# 1   58853106.0   Columbia Pictures    104.0               July 2, 1980
# 2  538375067.0           Lucasfilm    124.0              June 20, 1980
# 3   83453539.0  Paramount Pictures     88.0               July 2, 1980
# 4   39846344.0      Orion Pictures     98.0              July 25, 1980

# %% [markdown]
# # Split Country from 'Released column'

# %%
df.dtypes
# Out:
# name                           object
# rating                         object
# genre                          object
# year                            int64
# released                       object
# score                         float64
# votes                         float64
# director                       object
# writer                         object
# star                           object
# country                        object
# budget                        float64
# gross                         float64
# company                        object
# runtime                       float64
# date_released_afterremoved     object
# dtype: object

# %%
df.pop('released')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    score      votes         director                   writer            star  \
# 0    8.4   927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2    8.7  1200000.0   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3    7.7   221000.0     Jim Abrahams             Jim Abrahams     Robert Hays
# 4    7.3   108000.0     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country      budget        gross             company  runtime  \
# 0  United Kingdom  19000000.0   46998772.0        Warner Bros.    146.0
# 1   United States   4500000.0   58853106.0   Columbia Pictures    104.0
# 2   United States  18000000.0  538375067.0           Lucasfilm    124.0
# 3   United States   3500000.0   83453539.0  Paramount Pictures     88.0
# 4   United States   6000000.0   39846344.0      Orion Pictures     98.0
#
#   date_released_afterremoved
# 0              June 13, 1980
# 1               July 2, 1980
# 2              June 20, 1980
# 3               July 2, 1980
# 4              July 25, 1980

# %%
df.dtypes
# Out:
# name                           object
# rating                         object
# genre                          object
# year                            int64
# score                         float64
# votes                         float64
# director                       object
# writer                         object
# star                           object
# country                        object
# budget                        float64
# gross                         float64
# company                        object
# runtime                       float64
# date_released_afterremoved     object
# dtype: object

# %%
df['year_releasded_new'] = pd.DatetimeIndex(df['date_released_afterremoved']).year
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    score      votes         director                   writer            star  \
# 0    8.4   927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2    8.7  1200000.0   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3    7.7   221000.0     Jim Abrahams             Jim Abrahams     Robert Hays
# 4    7.3   108000.0     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country      budget        gross             company  runtime  \
# 0  United Kingdom  19000000.0   46998772.0        Warner Bros.    146.0
# 1   United States   4500000.0   58853106.0   Columbia Pictures    104.0
# 2   United States  18000000.0  538375067.0           Lucasfilm    124.0
# 3   United States   3500000.0   83453539.0  Paramount Pictures     88.0
# 4   United States   6000000.0   39846344.0      Orion Pictures     98.0
#
#   date_released_afterremoved  year_releasded_new
# 0              June 13, 1980              1980.0
# 1               July 2, 1980              1980.0
# 2              June 20, 1980              1980.0
# 3               July 2, 1980              1980.0
# 4              July 25, 1980              1980.0

# %%
df['year_releasded_new'] = df['year_releasded_new'].astype(str).str[:4]
df.dtypes
# Out:
# name                           object
# rating                         object
# genre                          object
# score                         float64
# votes                         float64
# director                       object
# writer                         object
# star                           object
# country                        object
# budget                        float64
# gross                         float64
# company                        object
# runtime                       float64
# date_released_afterremoved     object
# year_releasded_new             object
# dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#    score      votes         director                   writer            star  \
# 0    8.4   927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2    8.7  1200000.0   Irvin Kershner           Leigh Brackett     Mark Hamill
# 3    7.7   221000.0     Jim Abrahams             Jim Abrahams     Robert Hays
# 4    7.3   108000.0     Harold Ramis       Brian Doyle-Murray     Chevy Chase
#
#           country      budget        gross             company  runtime  \
# 0  United Kingdom  19000000.0   46998772.0        Warner Bros.    146.0
# 1   United States   4500000.0   58853106.0   Columbia Pictures    104.0
# 2   United States  18000000.0  538375067.0           Lucasfilm    124.0
# 3   United States   3500000.0   83453539.0  Paramount Pictures     88.0
# 4   United States   6000000.0   39846344.0      Orion Pictures     98.0
#
#   date_released_afterremoved year_releasded_new
# 0              June 13, 1980               1980
# 1               July 2, 1980               1980
# 2              June 20, 1980               1980
# 3               July 2, 1980               1980
# 4              July 25, 1980               1980

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %% [markdown]
# # DROP ANY NAN VALUES from budget and gross column

# %%
df = df.dropna(subset = ['budget', 'gross'])

# %%
df.head()
# Out:
#                                             name rating   genre  year  score  \
# 5445                                      Avatar  PG-13  Action  2009    7.8
# 7445                           Avengers: Endgame  PG-13  Action  2019    8.4
# 3045                                     Titanic  PG-13   Drama  1997    7.8
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015    7.8
# 7244                      Avengers: Infinity War  PG-13  Action  2018    8.4
#
#           votes       director              writer               star  \
# 5445  1100000.0  James Cameron       James Cameron    Sam Worthington
# 7445   903000.0  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000.0  James Cameron       James Cameron  Leonardo DiCaprio
# 6663   876000.0    J.J. Abrams     Lawrence Kasdan       Daisy Ridley
# 7244   897000.0  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#             country       budget         gross                company  \
# 5445  United States  237000000.0  2.847246e+09  Twentieth Century Fox
# 7445  United States  356000000.0  2.797501e+09         Marvel Studios
# 3045  United States  200000000.0  2.201647e+09  Twentieth Century Fox
# 6663  United States  245000000.0  2.069522e+09              Lucasfilm
# 7244  United States  321000000.0  2.048360e+09         Marvel Studios
#
#       runtime date_released_afterremoved year_releasded_new
# 5445    162.0          December 18, 2009               2009
# 7445    181.0             April 26, 2019               2019
# 3045    194.0          December 19, 1997               1997
# 6663    138.0          December 18, 2015               2015
# 7244    149.0             April 27, 2018               2018

# %%
df.pop('year')
df.head()
# Out:
#                                             name rating   genre  score  \
# 5445                                      Avatar  PG-13  Action    7.8
# 7445                           Avengers: Endgame  PG-13  Action    8.4
# 3045                                     Titanic  PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action    7.8
# 7244                      Avengers: Infinity War  PG-13  Action    8.4
#
#           votes       director              writer               star  \
# 5445  1100000.0  James Cameron       James Cameron    Sam Worthington
# 7445   903000.0  Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000.0  James Cameron       James Cameron  Leonardo DiCaprio
# 6663   876000.0    J.J. Abrams     Lawrence Kasdan       Daisy Ridley
# 7244   897000.0  Anthony Russo  Christopher Markus  Robert Downey Jr.
#
#             country       budget         gross                company  \
# 5445  United States  237000000.0  2.847246e+09  Twentieth Century Fox
# 7445  United States  356000000.0  2.797501e+09         Marvel Studios
# 3045  United States  200000000.0  2.201647e+09  Twentieth Century Fox
# 6663  United States  245000000.0  2.069522e+09              Lucasfilm
# 7244  United States  321000000.0  2.048360e+09         Marvel Studios
#
#       runtime date_released_afterremoved year_releasded_new
# 5445    162.0          December 18, 2009               2009
# 7445    181.0             April 26, 2019               2019
# 3045    194.0          December 19, 1997               1997
# 6663    138.0          December 18, 2015               2015
# 7244    149.0             April 27, 2018               2018

# %% [markdown]
# #  Scatter plot with budget vs gross

# %%
plt.scatter(x=df['budget'], y=df['gross'], color='cyan')
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for film')
plt.ylabel('Gross Earnings')
plt.show()

# %% [markdown]
# # Plot the correlation between Budget and Gross using Seaborn

# %%
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'cyan'}, line_kws={'color':'green'})
# Out:
# <AxesSubplot: xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson')
# Out:
# /var/folders/xn/t7qqntf55k9dw00kvrf28cww0000gn/T/ipykernel_18077/851377781.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                        score     votes    budget     gross   runtime  \
# score               1.000000  0.473809  0.071792  0.222143  0.414580
# votes               0.473809  1.000000  0.440021  0.614904  0.352437
# budget              0.071792  0.440021  1.000000  0.740395  0.318595
# gross               0.222143  0.614904  0.740395  1.000000  0.275596
# runtime             0.414580  0.352437  0.318595  0.275596  1.000000
# year_releasded_new  0.061029  0.202883  0.320245  0.268626  0.074432
#
#                     year_releasded_new
# score                         0.061029
# votes                         0.202883
# budget                        0.320245
# gross                         0.268626
# runtime                       0.074432
# year_releasded_new            1.000000

# %%
df['year_releasded_new'] = df['year_releasded_new'].astype(int)
df.dtypes
# Out:
# name                           object
# rating                         object
# genre                          object
# score                         float64
# votes                         float64
# director                       object
# writer                         object
# star                           object
# country                        object
# budget                        float64
# gross                         float64
# company                        object
# runtime                       float64
# date_released_afterremoved     object
# year_releasded_new              int64
# dtype: object

# %% [markdown]
# ## Relise that the high correlation between Budget vs Gross= 0.74, Gross vs Votes=0.61

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True, cmap='PiYG')
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()
# Out:
# /var/folders/xn/t7qqntf55k9dw00kvrf28cww0000gn/T/ipykernel_18077/380738121.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [115], line 5
#       3 sns.heatmap(correlation_matrix, annot=True, cmap='PiYG')
#       4 plt.title('Correlation Matric for Numeric Features')
# ----> 5 pit.xlabel('Movie Features')
#       6 plt.ylabel('Movie Features')
#       8 plt.show()
#
# NameError: name 'pit' is not defined

# %% [markdown]
# ## Convert object --> numberical to looking for more correlation

# %%
df_numerized = df
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
#       star  country      budget        gross  company  runtime
# 0     1047       54  19000000.0   46998772.0     2319    146.0
# 1      327       55   4500000.0   58853106.0      731    104.0
# 2     1745       55  18000000.0  538375067.0     1540    124.0
# 3     2246       55   3500000.0   83453539.0     1812     88.0
# 4      410       55   6000000.0   39846344.0     1777     98.0
# ...    ...      ...         ...          ...      ...      ...
# 7663  2421       55      7000.0          NaN       -1     90.0
# 7664  1886       55         NaN          NaN      539     90.0
# 7665  2040       55     58750.0          NaN      941      NaN
# 7666   450       55     15000.0          NaN       -1    120.0
# 7667  2463       44         NaN          NaN     1787    102.0
#
# [7668 rows x 15 columns]

# %%
df.head()
# Out:
#                                             name     rating   genre  score  \
# 5445                                      Avatar      PG-13  Action    7.8
# 7445                           Avengers: Endgame      PG-13  Action    8.4
# 3045                                     Titanic      PG-13   Drama    7.8
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action    7.8
# 7244                      Avengers: Infinity War      PG-13  Action    8.4
# ...                                          ...        ...     ...    ...
# 2434                  Philadelphia Experiment II      PG-13  Action    4.5
# 3681                                Ginger Snaps  Not Rated   Drama    6.8
# 272                                     Parasite          R  Horror    3.9
# 2417                                    Madadayo        NaN   Drama    7.3
# 3203                                  Trojan War      PG-13  Comedy    5.7
#
#           votes          director              writer               star  \
# 5445  1100000.0     James Cameron       James Cameron    Sam Worthington
# 7445   903000.0     Anthony Russo  Christopher Markus  Robert Downey Jr.
# 3045  1100000.0     James Cameron       James Cameron  Leonardo DiCaprio
# 6663   876000.0       J.J. Abrams     Lawrence Kasdan       Daisy Ridley
# 7244   897000.0     Anthony Russo  Christopher Markus  Robert Downey Jr.
# ...         ...               ...                 ...                ...
# 2434     1900.0  Stephen Cornwell  Wallace C. Bennett       Brad Johnson
# 3681    43000.0      John Fawcett        Karen Walton      Emily Perkins
# 272      2300.0      Charles Band       Alan J. Adler    Robert Glaudini
# 2417     5100.0    Akira Kurosawa        Ishirô Honda   Tatsuo Matsumura
# 3203     5800.0      George Huang           Andy Burg       Will Friedle
#
#             country       budget         gross  \
# 5445  United States  237000000.0  2.847246e+09
# 7445  United States  356000000.0  2.797501e+09
# 3045  United States  200000000.0  2.201647e+09
# 6663  United States  245000000.0  2.069522e+09
# 7244  United States  321000000.0  2.048360e+09
# ...             ...          ...           ...
# 2434  United States    5000000.0  2.970000e+03
# 3681         Canada    5000000.0  2.554000e+03
# 272   United States     800000.0  2.270000e+03
# 2417          Japan   11900000.0  5.960000e+02
# 3203  United States   15000000.0  3.090000e+02
#
#                              company  runtime date_released_afterremoved  \
# 5445           Twentieth Century Fox    162.0          December 18, 2009
# 7445                  Marvel Studios    181.0             April 26, 2019
# 3045           Twentieth Century Fox    194.0          December 19, 1997
# 6663                       Lucasfilm    138.0          December 18, 2015
# 7244                  Marvel Studios    149.0             April 27, 2018
# ...                              ...      ...                        ...
# 2434                Trimark Pictures     97.0               June 4, 1994
# 3681       Copperheart Entertainment    108.0               May 11, 2001
# 272                 Embassy Pictures     85.0             March 12, 1982
# 2417  DENTSU Music And Entertainment    134.0             April 17, 1993
# 3203                        Daybreak     85.0            October 1, 1997
#
#       year_releasded_new
# 5445                2009
# 7445                2019
# 3045                1997
# 6663                2015
# 7244                2018
# ...                  ...
# 2434                1994
# 3681                2001
# 272                 1982
# 2417                1993
# 3203                1997
#
# [5436 rows x 15 columns]

# %%
correlation_new_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_new_matrix, annot=True, cmap='PiYG')
plt.title('Correlation Matric for Numeric Features 2')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [40], line 1
# ----> 1 correlation_new_matrix = df_numerized.corr(method='pearson')
#       3 sns.heatmap(correlation_new_matrix, annot=True, cmap='PiYG')
#       4 plt.title('Correlation Matric for Numeric Features 2')
#
# NameError: name 'df_numerized' is not defined

# %%
df_numerized.corr()
# Out:
#                                 name    rating     genre     score     votes  \
# name                        1.000000 -0.023013  0.009617  0.014955  0.012915
# rating                     -0.023013  1.000000  0.128102  0.059550  0.009255
# genre                       0.009617  0.128102  1.000000  0.034061 -0.136457
# score                       0.014955  0.059550  0.034061  1.000000  0.473809
# votes                       0.012915  0.009255 -0.136457  0.473809  1.000000
# director                    0.013699  0.014847 -0.009303  0.005573 -0.010198
# writer                      0.011602 -0.006923  0.017500  0.012860 -0.005394
# star                       -0.007109  0.003737  0.002619  0.009121 -0.017140
# country                    -0.024555  0.020148 -0.010847 -0.044690  0.042146
# budget                      0.023698 -0.186892 -0.368900  0.071792  0.440021
# gross                       0.005966 -0.168814 -0.244380  0.222143  0.614904
# company                     0.021209 -0.082189 -0.073293  0.021054  0.119366
# runtime                     0.010800  0.133239 -0.060186  0.414580  0.352437
# date_released_afterremoved -0.005887  0.018096  0.020867  0.046659  0.029816
# year_releasded_new          0.024734  0.023634 -0.068848  0.061029  0.202883
#
#                             director    writer      star   country    budget  \
# name                        0.013699  0.011602 -0.007109 -0.024555  0.023698
# rating                      0.014847 -0.006923  0.003737  0.020148 -0.186892
# genre                      -0.009303  0.017500  0.002619 -0.010847 -0.368900
# score                       0.005573  0.012860  0.009121 -0.044690  0.071792
# votes                      -0.010198 -0.005394 -0.017140  0.042146  0.440021
# director                    1.000000  0.262940  0.036289  0.011108 -0.009340
# writer                      0.262940  1.000000  0.019273  0.022153 -0.039420
# star                        0.036289  0.019273  1.000000 -0.010135 -0.021282
# country                     0.011108  0.022153 -0.010135  1.000000  0.054372
# budget                     -0.009340 -0.039420 -0.021282  0.054372  1.000000
# gross                      -0.029366 -0.035999 -0.000009  0.060929  0.740395
# company                    -0.007337 -0.002658  0.015086  0.049559  0.171385
# runtime                     0.018082 -0.016672  0.012439 -0.033554  0.318595
# date_released_afterremoved  0.003518  0.008589  0.015209 -0.017051  0.021113
# year_releasded_new         -0.036281 -0.024397 -0.033168 -0.073732  0.320245
#
#                                gross   company   runtime  \
# name                        0.005966  0.021209  0.010800
# rating                     -0.168814 -0.082189  0.133239
# genre                      -0.244380 -0.073293 -0.060186
# score                       0.222143  0.021054  0.414580
# votes                       0.614904  0.119366  0.352437
# director                   -0.029366 -0.007337  0.018082
# writer                     -0.035999 -0.002658 -0.016672
# star                       -0.000009  0.015086  0.012439
# country                     0.060929  0.049559 -0.033554
# budget                      0.740395  0.171385  0.318595
# gross                       1.000000  0.150233  0.275596
# company                     0.150233  1.000000  0.038752
# runtime                     0.275596  0.038752  1.000000
# date_released_afterremoved  0.009791 -0.002501  0.008894
# year_releasded_new          0.268626 -0.017823  0.074432
#
#                             date_released_afterremoved  year_releasded_new
# name                                         -0.005887            0.024734
# rating                                        0.018096            0.023634
# genre                                         0.020867           -0.068848
# score                                         0.046659            0.061029
# votes                                         0.029816            0.202883
# director                                      0.003518           -0.036281
# writer                                        0.008589           -0.024397
# star                                          0.015209           -0.033168
# country                                      -0.017051           -0.073732
# budget                                        0.021113            0.320245
# gross                                         0.009791            0.268626
# company                                      -0.002501           -0.017823
# runtime                                       0.008894            0.074432
# date_released_afterremoved                    1.000000           -0.005721
# year_releasded_new                           -0.005721            1.000000

# %%
correlation_matrix_f = df_numerized.corr()
corr_pairs = correlation_matrix_f.unstack()
corr_pairs
# Out:
# name                name                          1.000000
#                     rating                       -0.023013
#                     genre                         0.009617
#                     score                         0.014955
#                     votes                         0.012915
#                                                     ...
# year_releasded_new  gross                         0.268626
#                     company                      -0.017823
#                     runtime                       0.074432
#                     date_released_afterremoved   -0.005721
#                     year_releasded_new            1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre                       budget                       -0.368900
# budget                      genre                        -0.368900
# genre                       gross                        -0.244380
# gross                       genre                        -0.244380
# budget                      rating                       -0.186892
#                                                             ...
# score                       score                         1.000000
# genre                       genre                         1.000000
# rating                      rating                        1.000000
# date_released_afterremoved  date_released_afterremoved    1.000000
# year_releasded_new          year_releasded_new            1.000000
# Length: 225, dtype: float64

# %%
high_corr = sorted_pairs[sorted_pairs > 0.4]
high_corr
# Out:
# runtime                     score                         0.414580
# score                       runtime                       0.414580
# votes                       budget                        0.440021
# budget                      votes                         0.440021
# score                       votes                         0.473809
# votes                       score                         0.473809
#                             gross                         0.614904
# gross                       votes                         0.614904
#                             budget                        0.740395
# budget                      gross                         0.740395
# name                        name                          1.000000
# star                        star                          1.000000
# runtime                     runtime                       1.000000
# company                     company                       1.000000
# gross                       gross                         1.000000
# budget                      budget                        1.000000
# country                     country                       1.000000
# writer                      writer                        1.000000
# director                    director                      1.000000
# votes                       votes                         1.000000
# score                       score                         1.000000
# genre                       genre                         1.000000
# rating                      rating                        1.000000
# date_released_afterremoved  date_released_afterremoved    1.000000
# year_releasded_new          year_releasded_new            1.000000
# dtype: float64

# %% [markdown]
# # Beside Budget+Gross / Gross+Votes, we can see Score and Votes also have HIGH CORRELATION
